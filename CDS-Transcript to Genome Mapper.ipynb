# %%
install.packages("remotes")
# Out:
# package 'remotes' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Samiksha\AppData\Local\Temp\RtmpUFdsL0\downloaded_packages

# %%
remotes::install_github("jotsetung/ensembldb")
# Out:
# Downloading GitHub repo jotsetung/ensembldb@master
# curl        (NA       -> 4.3     ) [CRAN]
# RCurl       (1.98-1.1 -> 1.98-1.2) [CRAN]
# pkgconfig   (2.0.2    -> 2.0.3   ) [CRAN]
# Rcpp        (1.0.1    -> 1.0.4.6 ) [CRAN]
# BH          (1.69.0-1 -> 1.72.0-3) [CRAN]
# digest      (0.6.18   -> 0.6.25  ) [CRAN]
# glue        (1.3.1    -> 1.4.0   ) [CRAN]
# formatR     (1.6      -> 1.7     ) [CRAN]
# progress    (1.2.0    -> 1.2.2   ) [CRAN]
# httr        (1.4.0    -> 1.4.1   ) [CRAN]
# openssl     (1.3      -> 1.4.1   ) [CRAN]
# dbplyr      (1.4.0    -> 1.4.3   ) [CRAN]
# dplyr       (0.8.0.1  -> 0.8.5   ) [CRAN]
# jsonlite    (1.6      -> 1.6.1   ) [CRAN]
# mime        (0.6      -> 0.9     ) [CRAN]
# R6          (2.4.0    -> 2.4.1   ) [CRAN]
# askpass     (1.0      -> 1.1     ) [CRAN]
# hms         (0.4.2    -> 0.5.3   ) [CRAN]
# prettyunits (1.0.2    -> 1.1.1   ) [CRAN]
# stringi     (1.4.3    -> 1.4.6   ) [CRAN]
# sys         (3.2      -> 3.3     ) [CRAN]
# lifecycle   (NA       -> 0.2.0   ) [CRAN]
# purrr       (0.3.2    -> 0.3.4   ) [CRAN]
# tibble      (2.1.1    -> 3.0.1   ) [CRAN]
# tidyselect  (0.2.5    -> 1.0.0   ) [CRAN]
# cli         (1.1.0    -> 2.0.2   ) [CRAN]
# fansi       (0.4.0    -> 0.4.1   ) [CRAN]
# pillar      (1.3.1    -> 1.4.3   ) [CRAN]
# Installing 28 packages: curl, RCurl, pkgconfig, Rcpp, BH, digest, glue, formatR, progress, httr, openssl, dbplyr, dplyr, jsonlite, mime, R6, askpass, hms, prettyunits, stringi, sys, lifecycle, purrr, tibble, tidyselect, cli, fansi, pillar
#   There are binary versions available but the source versions are later:
#          binary   source needs_compilation
# RCurl  1.98-1.1 1.98-1.2              TRUE
# tibble    3.0.0    3.0.1              TRUE
#
#   Binaries will be installed
# package 'curl' successfully unpacked and MD5 sums checked
# Error: Failed to install 'ensembldb' from GitHub:
#   (converted from warning) cannot remove prior installation of package 'curl'
# Traceback:
#
# 1. remotes::install_github("jotsetung/ensembldb")
# 2. install_remotes(remotes, auth_token = auth_token, host = host,
#  .     dependencies = dependencies, upgrade = upgrade, force = force,
#  .     quiet = quiet, build = build, build_opts = build_opts, build_manual = build_manual,
#  .     build_vignettes = build_vignettes, repos = repos, type = type,
#  .     ...)
# 3. tryCatch(res[[i]] <- install_remote(remotes[[i]], ...), error = function(e) {
#  .     stop(remote_install_error(remotes[[i]], e))
#  . })
# 4. tryCatchList(expr, classes, parentenv, handlers)
# 5. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 6. value[[3L]](cond)

# %%
remove.packages(curl)
# Out:
# Error in remove.packages(curl): object 'curl' not found
# Traceback:
#
# 1. remove.packages(curl)

# %%
library.packages(ensembldb)
# Out:
# Error in library.packages(ensembldb): could not find function "library.packages"
# Traceback:

# %%
install.packages("ensembldb")
# Out:
# Warning message:
# "package 'ensembldb' is not available (for R version 3.6.1)"

# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")
BiocManager::install()
# Out:
# Bioconductor version 3.10 (BiocManager 1.30.10), R 3.6.1 (2019-07-05)
# Old packages: 'askpass', 'backports', 'BH', 'bit', 'boot', 'broom', 'callr',
#   'caret', 'caTools', 'class', 'cli', 'clipr', 'cluster', 'data.table',
#   'dbplyr', 'digest', 'dplyr', 'evaluate', 'fansi', 'forcats', 'foreach',
#   'foreign', 'formatR', 'fs', 'ggplot2', 'glmnet', 'glue', 'gower', 'haven',
#   'hexbin', 'hms', 'htmltools', 'htmlwidgets', 'httpuv', 'httr', 'ipred',
#   'IRkernel', 'iterators', 'jsonlite', 'KernSmooth', 'knitr', 'later',
#   'lattice', 'lava', 'lubridate', 'markdown', 'MASS', 'Matrix', 'mgcv', 'mime',
#   'ModelMetrics', 'modelr', 'mongolite', 'nlme', 'nnet', 'numDeriv', 'odbc',
#   'openssl', 'pillar', 'pkgconfig', 'PKI', 'plyr', 'prettyunits', 'processx',
#   'prodlim', 'profvis', 'progress', 'promises', 'ps', 'purrr', 'quantmod',
#   'R6', 'Rcpp', 'RCurl', 'recipes', 'repr', 'reprex', 'reshape2', 'rJava',
#   'RJDBC', 'RJSONIO', 'rmarkdown', 'rsconnect', 'rstudioapi', 'rvest',
#   'scales', 'selectr', 'shiny', 'sparklyr', 'SQUAREM', 'stringi', 'survival',
#   'sys', 'tibble', 'tidyr', 'tidyselect', 'tidyverse', 'tinytex', 'TTR',
#   'uuid', 'whisker', 'withr', 'xfun', 'xml2', 'xts', 'yaml', 'zoo'

# %%
BiocManager::install("ensembldb")
# Out:
# Bioconductor version 3.10 (BiocManager 1.30.10), R 3.6.1 (2019-07-05)
# Installing package(s) 'ensembldb'
# also installing the dependency 'curl'
# package 'curl' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'curl'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\Samiksha\Downloads\Anaconda\envs\R\Lib\R\library\00LOCK\curl\libs\x64\curl.dll to C:\Users\Samiksha\Downloads\Anaconda\envs\R\Lib\R\library\curl\libs\x64\curl.dll: Permission denied"Warning message:
# "restored 'curl'"
# package 'ensembldb' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Samiksha\AppData\Local\Temp\RtmpUFdsL0\downloaded_packages
# Old packages: 'askpass', 'backports', 'BH', 'bit', 'boot', 'broom', 'callr',
#   'caret', 'caTools', 'class', 'cli', 'clipr', 'cluster', 'data.table',
#   'dbplyr', 'digest', 'dplyr', 'evaluate', 'fansi', 'forcats', 'foreach',
#   'foreign', 'formatR', 'fs', 'ggplot2', 'glmnet', 'glue', 'gower', 'haven',
#   'hexbin', 'hms', 'htmltools', 'htmlwidgets', 'httpuv', 'httr', 'ipred',
#   'IRkernel', 'iterators', 'jsonlite', 'KernSmooth', 'knitr', 'later',
#   'lattice', 'lava', 'lubridate', 'markdown', 'MASS', 'Matrix', 'mgcv', 'mime',
#   'ModelMetrics', 'modelr', 'mongolite', 'nlme', 'nnet', 'numDeriv', 'odbc',
#   'openssl', 'pillar', 'pkgconfig', 'PKI', 'plyr', 'prettyunits', 'processx',
#   'prodlim', 'profvis', 'progress', 'promises', 'ps', 'purrr', 'quantmod',
#   'R6', 'Rcpp', 'RCurl', 'recipes', 'repr', 'reprex', 'reshape2', 'rJava',
#   'RJDBC', 'RJSONIO', 'rmarkdown', 'rsconnect', 'rstudioapi', 'rvest',
#   'scales', 'selectr', 'shiny', 'sparklyr', 'SQUAREM', 'stringi', 'survival',
#   'sys', 'tibble', 'tidyr', 'tidyselect', 'tidyverse', 'tinytex', 'TTR',
#   'uuid', 'whisker', 'withr', 'xfun', 'xml2', 'xts', 'yaml', 'zoo'

# %%
BiocManager::install("AnnotationHub")
# Out:
# Bioconductor version 3.10 (BiocManager 1.30.10), R 3.6.1 (2019-07-05)
# Installing package(s) 'AnnotationHub'
# also installing the dependencies 'curl', 'interactiveDisplayBase'
# package 'curl' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'curl'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\Samiksha\Downloads\Anaconda\envs\R\Lib\R\library\00LOCK\curl\libs\x64\curl.dll to C:\Users\Samiksha\Downloads\Anaconda\envs\R\Lib\R\library\curl\libs\x64\curl.dll: Permission denied"Warning message:
# "restored 'curl'"
# package 'interactiveDisplayBase' successfully unpacked and MD5 sums checked
# package 'AnnotationHub' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Samiksha\AppData\Local\Temp\RtmpUFdsL0\downloaded_packages
# Old packages: 'askpass', 'backports', 'BH', 'bit', 'boot', 'broom', 'callr',
#   'caret', 'caTools', 'class', 'cli', 'clipr', 'cluster', 'data.table',
#   'dbplyr', 'digest', 'dplyr', 'evaluate', 'fansi', 'forcats', 'foreach',
#   'foreign', 'formatR', 'fs', 'ggplot2', 'glmnet', 'glue', 'gower', 'haven',
#   'hexbin', 'hms', 'htmltools', 'htmlwidgets', 'httpuv', 'httr', 'ipred',
#   'IRkernel', 'iterators', 'jsonlite', 'KernSmooth', 'knitr', 'later',
#   'lattice', 'lava', 'lubridate', 'markdown', 'MASS', 'Matrix', 'mgcv', 'mime',
#   'ModelMetrics', 'modelr', 'mongolite', 'nlme', 'nnet', 'numDeriv', 'odbc',
#   'openssl', 'pillar', 'pkgconfig', 'PKI', 'plyr', 'prettyunits', 'processx',
#   'prodlim', 'profvis', 'progress', 'promises', 'ps', 'purrr', 'quantmod',
#   'R6', 'Rcpp', 'RCurl', 'recipes', 'repr', 'reprex', 'reshape2', 'rJava',
#   'RJDBC', 'RJSONIO', 'rmarkdown', 'rsconnect', 'rstudioapi', 'rvest',
#   'scales', 'selectr', 'shiny', 'sparklyr', 'SQUAREM', 'stringi', 'survival',
#   'sys', 'tibble', 'tidyr', 'tidyselect', 'tidyverse', 'tinytex', 'TTR',
#   'uuid', 'whisker', 'withr', 'xfun', 'xml2', 'xts', 'yaml', 'zoo'

# %%
browseVignettes("AnnotationHub")
# Out:
# starting httpd help server ... done

# %%
help(AnnotationHub)
# Out:
# Warning message in read.dcf(file.path(p, "DESCRIPTION"), c("Package", "Version")):
# "cannot open compressed file 'C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library/curl/DESCRIPTION', probable reason 'No such file or directory'"Warning message in find.package(if (is.null(package)) loadedNamespaces() else package, :
# "there is no package called 'curl'"

# %%
'??AnnotationHub'
# Out:
# [1] "??AnnotationHub"

# %%
installed.packages()
# Out:
#                             Package
# AnnotationDbi               AnnotationDbi
# AnnotationFilter            AnnotationFilter
# AnnotationHub               AnnotationHub
# askpass                     askpass
# assertthat                  assertthat
# backports                   backports
# base                        base
# base64enc                   base64enc
# BH                          BH
# Biobase                     Biobase
# BiocFileCache               BiocFileCache
# BiocGenerics                BiocGenerics
# BiocManager                 BiocManager
# BiocParallel                BiocParallel
# BiocVersion                 BiocVersion
# biomaRt                     biomaRt
# Biostrings                  Biostrings
# bit                         bit
# bit64                       bit64
# bitops                      bitops
# blob                        blob
# boot                        boot
# broom                       broom
# BSgenome                    BSgenome
# BSgenome.Celegans.UCSC.ce11 BSgenome.Celegans.UCSC.ce11
# callr                       callr
# caret                       caret
# caTools                     caTools
# cellranger                  cellranger
# class                       class
# ...                         ...
# stringr                     stringr
# SummarizedExperiment        SummarizedExperiment
# survival                    survival
# sys                         sys
# tcltk                       tcltk
# tibble                      tibble
# tidyr                       tidyr
# tidyselect                  tidyselect
# tidyverse                   tidyverse
# timeDate                    timeDate
# tinytex                     tinytex
# tools                       tools
# translations                translations
# TTR                         TTR
# utf8                        utf8
# utils                       utils
# uuid                        uuid
# vctrs                       vctrs
# viridisLite                 viridisLite
# whisker                     whisker
# withr                       withr
# xfun                        xfun
# XML                         XML
# xml2                        xml2
# xtable                      xtable
# xts                         xts
# XVector                     XVector
# yaml                        yaml
# zlibbioc                    zlibbioc
# zoo                         zoo
#                             LibPath
# AnnotationDbi               C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# AnnotationFilter            C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# AnnotationHub               C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# askpass                     C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# assertthat                  C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# backports                   C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# base                        C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# base64enc                   C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# BH                          C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# Biobase                     C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# BiocFileCache               C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# BiocGenerics                C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# BiocManager                 C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# BiocParallel                C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# BiocVersion                 C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# biomaRt                     C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# Biostrings                  C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# bit                         C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# bit64                       C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# bitops                      C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# blob                        C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# boot                        C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# broom                       C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# BSgenome                    C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# BSgenome.Celegans.UCSC.ce11 C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# callr                       C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# caret                       C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# caTools                     C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# cellranger                  C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# class                       C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# ...                         ...
# stringr                     C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# SummarizedExperiment        C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# survival                    C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# sys                         C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# tcltk                       C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# tibble                      C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# tidyr                       C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# tidyselect                  C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# tidyverse                   C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# timeDate                    C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# tinytex                     C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# tools                       C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# translations                C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# TTR                         C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# utf8                        C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# utils                       C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# uuid                        C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# vctrs                       C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# viridisLite                 C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# whisker                     C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# withr                       C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# xfun                        C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# XML                         C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# xml2                        C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# xtable                      C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# xts                         C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# XVector                     C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# yaml                        C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# zlibbioc                    C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
# zoo                         C:/Users/Samiksha/Downloads/Anaconda/envs/R/Lib/R/library
#                             Version  Priority
# AnnotationDbi               1.48.0   NA
# AnnotationFilter            1.10.0   NA
# AnnotationHub               2.18.0   NA
# askpass                     1.0      NA
# assertthat                  0.2.1    NA
# backports                   1.1.4    NA
# base                        3.6.1    base
# base64enc                   0.1-3    NA
# BH                          1.69.0-1 NA
# Biobase                     2.46.0   NA
# BiocFileCache               1.10.2   NA
# BiocGenerics                0.32.0   NA
# BiocManager                 1.30.10  NA
# BiocParallel                1.20.1   NA
# BiocVersion                 3.10.1   NA
# biomaRt                     2.42.1   NA
# Biostrings                  2.54.0   NA
# bit                         1.1-14   NA
# bit64                       0.9-7    NA
# bitops                      1.0-6    NA
# blob                        1.2.1    NA
# boot                        1.3-20   recommended
# broom                       0.5.2    NA
# BSgenome                    1.54.0   NA
# BSgenome.Celegans.UCSC.ce11 1.4.2    NA
# callr                       3.2.0    NA
# caret                       6.0-83   NA
# caTools                     1.17.1.2 NA
# cellranger                  1.1.0    NA
# class                       7.3-15   recommended
# ...                         ...      ...
# stringr                     1.4.0    NA
# SummarizedExperiment        1.16.1   NA
# survival                    2.44-1.1 recommended
# sys                         3.2      NA
# tcltk                       3.6.1    base
# tibble                      2.1.1    NA
# tidyr                       0.8.3    NA
# tidyselect                  0.2.5    NA
# tidyverse                   1.2.1    NA
# timeDate                    3043.102 NA
# tinytex                     0.12     NA
# tools                       3.6.1    base
# translations                3.6.1    NA
# TTR                         0.23-4   NA
# utf8                        1.1.4    NA
# utils                       3.6.1    base
# uuid                        0.1-2    NA
# vctrs                       0.2.4    NA
# viridisLite                 0.3.0    NA
# whisker                     0.3-2    NA
# withr                       2.1.2    NA
# xfun                        0.6      NA
# XML                         3.99-0.3 NA
# xml2                        1.2.0    NA
# xtable                      1.8-4    NA
# xts                         0.11-2   NA
# XVector                     0.26.0   NA
# yaml                        2.2.0    NA
# zlibbioc                    1.32.0   NA
# zoo                         1.8-5    NA
#                             Depends
# AnnotationDbi               R (>= 2.7.0), methods, utils, stats4, BiocGenerics (>=\n0.29.2), Biobase (>= 1.17.0), IRanges
# AnnotationFilter            R (>= 3.4.0)
# AnnotationHub               BiocGenerics (>= 0.15.10), BiocFileCache (>= 1.5.1)
# askpass                     NA
# assertthat                  NA
# backports                   R (>= 3.0.0)
# base                        NA
# base64enc                   R (>= 2.9.0)
# BH                          NA
# Biobase                     R (>= 2.10), BiocGenerics (>= 0.27.1), utils
# BiocFileCache               R (>= 3.4.0), dbplyr (>= 1.0.0)
# BiocGenerics                R (>= 3.6.0), methods, utils, graphics, stats, parallel
# BiocManager                 NA
# BiocParallel                methods
# BiocVersion                 R (>= 3.6.0)
# biomaRt                     methods
# Biostrings                  R (>= 3.5.0), methods, BiocGenerics (>= 0.31.5), S4Vectors (>=\n0.21.13), IRanges, XVector (>= 0.23.2)
# bit                         R (>= 2.9.2)
# bit64                       R (>= 3.0.1), bit (>= 1.1-12), utils, methods, stats
# bitops                      NA
# blob                        NA
# boot                        R (>= 3.0.0), graphics, stats
# broom                       R (>= 3.1)
# BSgenome                    R (>= 2.8.0), methods, BiocGenerics (>= 0.13.8), S4Vectors (>=\n0.17.28), IRanges (>= 2.13.16), GenomeInfoDb (>= 1.15.2),\nGenomicRanges (>= 1.31.10), Biostrings (>= 2.47.6), rtracklayer\n(>= 1.39.7)
# BSgenome.Celegans.UCSC.ce11 BSgenome (>= 1.36.0)
# callr                       NA
# caret                       R (>= 3.5.0), lattice (>= 0.20), ggplot2
# caTools                     R (>= 2.2.0)
# cellranger                  R (>= 3.0.0)
# class                       R (>= 3.0.0), stats, utils
# ...                         ...
# stringr                     R (>= 3.1)
# SummarizedExperiment        R (>= 3.2), methods, GenomicRanges (>= 1.33.6), Biobase,\nDelayedArray (>= 0.3.20)
# survival                    R (>= 2.13.0)
# sys                         NA
# tcltk                       NA
# tibble                      R (>= 3.1.0)
# tidyr                       R (>= 3.1)
# tidyselect                  R (>= 3.1)
# tidyverse                   NA
# timeDate                    R (>= 2.15.1), graphics, utils, stats, methods
# tinytex                     NA
# tools                       NA
# translations                NA
# TTR                         NA
# utf8                        R (>= 2.10)
# utils                       NA
# uuid                        R (>= 2.9.0)
# vctrs                       R (>= 3.2)
# viridisLite                 R (>= 2.10)
# whisker                     NA
# withr                       R (>= 3.0.2)
# xfun                        NA
# XML                         R (>= 2.13.0), methods, utils
# xml2                        R (>= 3.1.0)
# xtable                      R (>= 2.10.0)
# xts                         zoo (>= 1.7-12)
# XVector                     R (>= 2.8.0), methods, BiocGenerics (>= 0.19.2), S4Vectors (>=\n0.21.13), IRanges (>= 2.15.12)
# yaml                        NA
# zlibbioc                    NA
# zoo                         R (>= 3.1.0), stats
#                             Imports
# AnnotationDbi               DBI, RSQLite, S4Vectors (>= 0.9.25)
# AnnotationFilter            utils, methods, GenomicRanges, lazyeval
# AnnotationHub               utils, methods, grDevices, RSQLite, BiocManager, BiocVersion,\ncurl, rappdirs, AnnotationDbi (>= 1.31.19), S4Vectors,\ninteractiveDisplayBase, httr, yaml, dplyr
# askpass                     sys (>= 2.1)
# assertthat                  tools
# backports                   utils
# base                        NA
# base64enc                   NA
# BH                          NA
# Biobase                     methods
# BiocFileCache               methods, stats, utils, dplyr, RSQLite, DBI, rappdirs, curl,\nhttr
# BiocGenerics                methods, utils, graphics, stats, parallel
# BiocManager                 utils
# BiocParallel                stats, utils, futile.logger, parallel, snow
# BiocVersion                 NA
# biomaRt                     utils, XML, AnnotationDbi, progress, stringr, httr, openssl,\nBiocFileCache, rappdirs
# Biostrings                  graphics, methods, stats, utils
# bit                         NA
# bit64                       NA
# bitops                      NA
# blob                        methods, rlang, vctrs (>= 0.2.1)
# boot                        NA
# broom                       backports, dplyr, generics (>= 0.0.2), methods, nlme, purrr,\nreshape2, stringr, tibble, tidyr
# BSgenome                    methods, utils, stats, BiocGenerics, S4Vectors, IRanges,\nXVector, GenomeInfoDb, GenomicRanges, Biostrings, Rsamtools,\nrtracklayer
# BSgenome.Celegans.UCSC.ce11 BSgenome
# callr                       processx (>= 3.3.0), R6, utils
# caret                       foreach, methods, plyr, ModelMetrics (>= 1.1.0), nlme,\nreshape2, stats, stats4, utils, grDevices, recipes (>= 0.1.4),\nwithr (>= 2.0.0)
# caTools                     bitops
# cellranger                  rematch, tibble
# class                       MASS
# ...                         ...
# stringr                     glue (>= 1.2.0), magrittr, stringi (>= 1.1.7)
# SummarizedExperiment        utils, stats, tools, Matrix, BiocGenerics (>= 0.15.3),\nS4Vectors (>= 0.23.20), IRanges (>= 2.13.16), GenomeInfoDb (>=\n1.13.1)
# survival                    graphics, Matrix, methods, splines, stats, utils
# sys                         NA
# tcltk                       utils
# tibble                      cli (>= 1.0.1), crayon (>= 1.3.4), fansi (>= 0.4.0), methods,\npillar (>= 1.3.1), pkgconfig (>= 2.0.2), rlang (>= 0.3.1),\nutils
# tidyr                       dplyr (>= 0.7.0), glue, magrittr, purrr, Rcpp, rlang, stringi,\ntibble, tidyselect (>= 0.2.5), utils
# tidyselect                  glue (>= 1.3.0), purrr, rlang (>= 0.2.2), Rcpp (>= 0.12.0)
# tidyverse                   broom (>= 0.4.2), cli (>= 1.0.0), crayon (>= 1.3.4), dplyr (>=\n0.7.4), dbplyr (>= 1.1.0), forcats (>= 0.2.0), ggplot2 (>=\n2.2.1), haven (>= 1.1.0), hms (>= 0.3), httr (>= 1.3.1),\njsonlite (>= 1.5), lubridate (>= 1.7.1), magrittr (>= 1.5),\nmodelr (>= 0.1.1), purrr (>= 0.2.4), readr (>= 1.1.1), readxl\n(>= 1.0.0), reprex (>= 0.1.1), rlang (>= 0.1.4), rstudioapi (>=\n0.7), rvest (>= 0.3.2), stringr (>= 1.2.0), tibble (>= 1.3.4),\ntidyr (>= 0.7.2), xml2 (>= 1.1.1)
# timeDate                    NA
# tinytex                     xfun (>= 0.5)
# tools                       NA
# ...
# zoo                         coda, chron, DAAG, fts, ggplot2, mondate, scales,\nstrucchange, timeDate, timeSeries, tis, tseries, xts
#                             Enhances
# AnnotationDbi               NA
# AnnotationFilter            NA
# AnnotationHub               AnnotationHubData
# askpass                     NA
# assertthat                  NA
# backports                   NA
# base                        NA
# base64enc                   png
# BH                          NA
# Biobase                     NA
# BiocFileCache               NA
# BiocGenerics                NA
# BiocManager                 NA
# BiocParallel                NA
# BiocVersion                 NA
# biomaRt                     NA
# Biostrings                  Rmpi
# bit                         NA
# bit64                       NA
# bitops                      NA
# blob                        NA
# boot                        NA
# broom                       NA
# BSgenome                    NA
# BSgenome.Celegans.UCSC.ce11 NA
# callr                       NA
# caret                       NA
# caTools                     NA
# cellranger                  NA
# class                       NA
# ...                         ...
# stringr                     NA
# SummarizedExperiment        NA
# survival                    NA
# sys                         NA
# tcltk                       NA
# tibble                      NA
# tidyr                       NA
# tidyselect                  NA
# tidyverse                   NA
# timeDate                    NA
# tinytex                     NA
# tools                       NA
# translations                NA
# TTR                         quantmod
# utf8                        NA
# utils                       NA
# uuid                        NA
# vctrs                       NA
# viridisLite                 NA
# whisker                     NA
# withr                       NA
# xfun                        NA
# XML                         NA
# xml2                        NA
# xtable                      NA
# xts                         NA
# XVector                     NA
# yaml                        NA
# zlibbioc                    NA
# zoo                         NA
#                             License
# AnnotationDbi               Artistic-2.0
# AnnotationFilter            Artistic-2.0
# AnnotationHub               Artistic-2.0
# askpass                     MIT + file LICENSE
# assertthat                  GPL-3
# backports                   GPL-2
# base                        Part of R 3.6.1
# base64enc                   GPL-2 | GPL-3
# BH                          BSL-1.0
# Biobase                     Artistic-2.0
# BiocFileCache               Artistic-2.0
# BiocGenerics                Artistic-2.0
# BiocManager                 Artistic-2.0
# BiocParallel                GPL-2 | GPL-3
# BiocVersion                 Artistic-2.0
# biomaRt                     Artistic-2.0
# Biostrings                  Artistic-2.0
# bit                         GPL-2
# bit64                       GPL-2
# bitops                      GPL (>= 2)
# blob                        GPL-3
# boot                        Unlimited
# broom                       MIT + file LICENSE
# BSgenome                    Artistic-2.0
# BSgenome.Celegans.UCSC.ce11 Artistic-2.0
# callr                       MIT + file LICENSE
# caret                       GPL (>= 2)
# caTools                     GPL-3
# cellranger                  MIT + file LICENSE
# class                       GPL-2 | GPL-3
# ...                         ...
# stringr                     GPL-2 | file LICENSE
# SummarizedExperiment        Artistic-2.0
# survival                    LGPL (>= 2)
# sys                         MIT + file LICENSE
# tcltk                       Part of R 3.6.1
# tibble                      MIT + file LICENSE
# tidyr                       MIT + file LICENSE
# tidyselect                  GPL-3
# tidyverse                   GPL-3 | file LICENSE
# timeDate                    GPL (>= 2)
# tinytex                     MIT + file LICENSE
# tools                       Part of R 3.6.1
# translations                Part of R 3.6.1
# TTR                         GPL-2
# utf8                        Apache License (== 2.0) | file LICENSE
# utils                       Part of R 3.6.1
# uuid                        MIT + file LICENSE
# vctrs                       GPL-3
# viridisLite                 MIT + file LICENSE
# whisker                     GPL-3
# withr                       GPL (>= 2)
# xfun                        MIT + file LICENSE
# XML                         BSD_3_clause + file LICENSE
# xml2                        GPL (>= 2)
# xtable                      GPL (>= 2)
# xts                         GPL (>= 2)
# XVector                     Artistic-2.0
# yaml                        BSD_3_clause + file LICENSE
# zlibbioc                    Artistic-2.0 + file LICENSE
# zoo                         GPL-2 | GPL-3
#                             License_is_FOSS License_restricts_use OS_type
# AnnotationDbi               NA              NA                    NA
# AnnotationFilter            NA              NA                    NA
# AnnotationHub               NA              NA                    NA
# askpass                     NA              NA                    NA
# assertthat                  NA              NA                    NA
# backports                   NA              NA                    NA
# base                        NA              NA                    NA
# base64enc                   NA              NA                    NA
# BH                          NA              NA                    NA
# Biobase                     NA              NA                    NA
# BiocFileCache               NA              NA                    NA
# BiocGenerics                NA              NA                    NA
# BiocManager                 NA              NA                    NA
# BiocParallel                NA              NA                    NA
# BiocVersion                 NA              NA                    NA
# biomaRt                     NA              NA                    NA
# Biostrings                  NA              NA                    NA
# bit                         NA              NA                    NA
# bit64                       NA              NA                    NA
# bitops                      NA              NA                    NA
# blob                        NA              NA                    NA
# boot                        NA              NA                    NA
# broom                       NA              NA                    NA
# BSgenome                    NA              NA                    NA
# BSgenome.Celegans.UCSC.ce11 NA              NA                    NA
# callr                       NA              NA                    NA
# caret                       NA              NA                    NA
# caTools                     NA              NA                    NA
# cellranger                  NA              NA                    NA
# class                       NA              NA                    NA
# ...                         ...             ...                   ...
# stringr                     NA              NA                    NA
# SummarizedExperiment        NA              NA                    NA
# survival                    NA              NA                    NA
# sys                         NA              NA                    NA
# tcltk                       NA              NA                    NA
# tibble                      NA              NA                    NA
# tidyr                       NA              NA                    NA
# tidyselect                  NA              NA                    NA
# tidyverse                   NA              NA                    NA
# timeDate                    NA              NA                    NA
# tinytex                     NA              NA                    NA
# tools                       NA              NA                    NA
# translations                NA              NA                    NA
# TTR                         NA              NA                    NA
# utf8                        NA              NA                    NA
# utils                       NA              NA                    NA
# uuid                        NA              NA                    NA
# vctrs                       NA              NA                    NA
# viridisLite                 NA              NA                    NA
# whisker                     NA              NA                    NA
# withr                       NA              NA                    NA
# xfun                        NA              NA                    NA
# XML                         NA              NA                    NA
# xml2                        NA              NA                    NA
# xtable                      NA              NA                    NA
# xts                         NA              NA                    NA
# XVector                     NA              NA                    NA
# yaml                        NA              NA                    NA
# zlibbioc                    NA              NA                    NA
# zoo                         NA              NA                    NA
#                             MD5sum NeedsCompilation Built
# AnnotationDbi               NA     no               3.6.1
# AnnotationFilter            NA     no               3.6.1
# AnnotationHub               NA     yes              3.6.1
# askpass                     NA     yes              3.6.0
# assertthat                  NA     no               3.6.0
# backports                   NA     yes              3.6.0
# base                        NA     NA               3.6.1
# base64enc                   NA     yes              3.6.0
# BH                          NA     no               3.6.0
# Biobase                     NA     yes              3.6.1
# BiocFileCache               NA     no               3.6.1
# BiocGenerics                NA     no               3.6.1
# BiocManager                 NA     no               3.6.3
# BiocParallel                NA     yes              3.6.2
# BiocVersion                 NA     no               3.6.0
# biomaRt                     NA     no               3.6.3
# Biostrings                  NA     yes              3.6.1
# bit                         NA     yes              3.6.0
# bit64                       NA     yes              3.6.0
# bitops                      NA     yes              3.6.0
# blob                        NA     no               3.6.1
# boot                        NA     no               3.6.0
# broom                       NA     no               3.6.0
# BSgenome                    NA     no               3.6.1
# BSgenome.Celegans.UCSC.ce11 NA     no               3.6.1
# callr                       NA     no               3.6.0
# caret                       NA     yes              3.6.0
# caTools                     NA     yes              3.6.0
# cellranger                  NA     no               3.6.0
# class                       NA     yes              3.6.0
# ...                         ...    ...              ...
# stringr                     NA     no               3.6.0
# SummarizedExperiment        NA     no               3.6.2
# survival                    NA     yes              3.6.0
# sys                         NA     yes              3.6.0
# tcltk                       NA     yes              3.6.1
# tibble                      NA     yes              3.6.0
# tidyr                       NA     yes              3.6.0
# tidyselect                  NA     yes              3.6.0
# tidyverse                   NA     no               3.6.0
# timeDate                    NA     no               3.6.0
# tinytex                     NA     no               3.6.0
# tools                       NA     yes              3.6.1
# translations                NA     NA               3.6.1
# TTR                         NA     yes              3.6.0
# utf8                        NA     yes              3.6.0
# utils                       NA     yes              3.6.1
# uuid                        NA     yes              3.6.0
# vctrs                       NA     yes              3.6.3
# viridisLite                 NA     no               3.6.0
# whisker                     NA     no               3.6.0
# withr                       NA     no               3.6.0
# xfun                        NA     no               3.6.0
# XML                         NA     yes              3.6.2
# xml2                        NA     yes              3.6.0
# xtable                      NA     no               3.6.0
# xts                         NA     yes              3.6.0
# XVector                     NA     yes              3.6.1
# yaml                        NA     yes              3.6.0
# zlibbioc                    NA     yes              3.6.1
# zoo                         NA     yes              3.6.0

# %%
AnnotationHub
# Out:
# Error in eval(expr, envir, enclos): object 'AnnotationHub' not found
# Traceback:

# %%
library(AnnotationHub)

# %%
ah <- AnnotationHub()
# Out:
# Using temporary cache C:\Users\Samiksha\AppData\Local\Temp\RtmpUFdsL0/BiocFileCache
# Warning message:
# "download failed
#   web resource path: 'https://annotationhub.bioconductor.org/metadata/annotationhub.sqlite3'
#   local file path: 'C:\Users\Samiksha\AppData\Local\Temp\RtmpUFdsL0/BiocFileCache/1efc1c0c40db_annotationhub.sqlite3'
#   reason: there is no package called 'curl'"Warning message:
# "bfcadd() failed; resource removed
#   rid: BFC2
#   fpath: 'https://annotationhub.bioconductor.org/metadata/annotationhub.sqlite3'
#   reason: download failed"
# Error in .util_download(x, rid[i], proxy, config, "bfcadd()", ...): bfcadd() failed; see warnings()
# Traceback:
#
# 1. AnnotationHub()
# 2. .Hub("AnnotationHub", hub, cache, proxy, localHub, ...)
# 3. .create_cache(.class, url, cache, proxy, localHub)
# 4. .updateHubDB(hub_bfc, .class, url, proxy, localHub)
# 5. bfcadd(bfc, rname = paste0(tolower(.class), ".sqlite3"), fpath = remote_db,
#  .     proxy = proxy)
# 6. bfcadd(bfc, rname = paste0(tolower(.class), ".sqlite3"), fpath = remote_db,
#  .     proxy = proxy)
# 7. .util_download(x, rid[i], proxy, config, "bfcadd()", ...)
# 8. stop(call, " failed; see warnings()")

# %%
install.packages("curl")
# Out:
# package 'curl' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'curl'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\Samiksha\Downloads\Anaconda\envs\R\Lib\R\library\00LOCK\curl\libs\x64\curl.dll to C:\Users\Samiksha\Downloads\Anaconda\envs\R\Lib\R\library\curl\libs\x64\curl.dll: Permission denied"Warning message:
# "restored 'curl'"
# The downloaded binary packages are in
# 	C:\Users\Samiksha\AppData\Local\Temp\RtmpUFdsL0\downloaded_packages

# %%
library(curl)
# Out:
# Error in library(curl): there is no package called 'curl'
# Traceback:
#
# 1. library(curl)
